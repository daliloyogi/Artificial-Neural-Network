# %% [markdown]
# # ***Artificial Neural Network practice*** 🥶
#
#
#
#
# ---
#
#
#
# > Nama : Dalilo Yogi Essy Pratama
#
# > NIM  : 5311422078
#
#
#
#
# ---

# %% [markdown]
# In this session I will practice about How to use *Artificial Neural Network* algorithm to processing and computating data. I use the *cars price prediction* dataset that available in *kaggle.* *Let's get straight to the practice!* 📗📗📗

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# *first,* to use the ANN algorithm we need some libraries to be use, the syntax above is about to include or import the commonly used libraries for data analysis, visualization, and machine learning. Here fo the details::
#
#
# 1.   **NumPy ( `import numpy as np` ):**
#
#
# > NumPy is a library for numerical operations in Python. It provides support for large, multi-dimensional arrays and matrices, along with mathematical functions to operate on these elements.
#
#
# 2.   **Pandas (`import pandas as pd`):**
#
#
# > Pandas is a powerful data manipulation library. It provides data structures like DataFrame for efficient data handling and analysis.
#
# 3. **Matplotlib (`import matplotlib.pyplot as plt`):**
#
#
#
# > Matplotlib is a popular plotting library in Python. It is used for creating static, interactive, and animated visualizations in Python.
#
# 4. **Seaborn (`import seaborn as sns`):**
#
#
# > Seaborn is a statistical data visualization library that is built on top of Matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# 5. **Scikit-learn (`from sklearn.model_selection import train_test_split`):**
#
#
# > Scikit-learn is a machine learning library in Python. It includes various tools for classification, regression, clustering, and more. The train_test_split function is used for splitting datasets into training and testing sets.
#
#
# 6. **Scikit-learn (`from sklearn.preprocessing import MinMaxScaler`):**
#
#
# > Another import from Scikit-learn. The MinMaxScaler is used for scaling features to a specified range, often between 0 and 1.
#
#
# 7. **TensorFlow (`from tensorflow.keras.models import Sequential and from tensorflow.keras.layers import Dense`):**
#
#
# > TensorFlow is an open-source machine learning framework. Here, you're importing the Sequential model from Keras, which is a high-level neural networks API running on top of TensorFlow. The Dense layer represents a fully connected layer in a neural network.
#
#
# 8. **Scikit-learn (`from sklearn.linear_model import LinearRegression`):**
#
#
# > Scikit-learn is imported again, and this time the LinearRegression class is imported. This class is used for linear regression, a common technique in statistical modeling.
#
#
# 9. **Scikit-learn (`from sklearn.metrics import r2_score`):**
#
#
# > The r2_score function is used for evaluating the performance of a regression model by calculating the R-squared value.
#
# ---
# ---

# %%
# Reading a CSV file into a Pandas DataFrame
df = pd.read_csv('/content/car_purchasing.csv', encoding='ISO-8859-1')
# Displaying the first few rows of the DataFrame
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# ...

# %% [markdown]
# In these lines, I am reading a CSV file named 'car_purchasing.csv' located at the path '/content/'. The `read_csv` function from Pandas is used to load the data into a DataFrame (`df`). The `encoding='ISO-8859-1'` parameter is specified to handle any potential character encoding issues in the CSV file.
#
# After loading the data, I use the`head` method to display the first five rows of the DataFrame. This is a quick way to inspect the structure and content of the dataset, providing an initial overview of the information stored in the 'car_purchasing.csv' file.
#
# ---

# %%
# Dropping columns not needed for modeling
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)

# %% [markdown]
# In this code, unnecessary columns ('customer name', 'customer e-mail', 'country', 'gender') are removed from the DataFrame df to streamline the dataset for modeling purposes.
#
# the `drop` method in Pandas to remove specific columns from the DataFrame `df`.
#
# The `inplace=True` parameter ensures that the modification is done directly on the original DataFrame, rather than creating a new one. Consequently, after the execution of this line, the DataFrame `df` will no longer contain the specified columns, as they have been effectively removed from the dataset.

# %%
df.head()
# Out:
#          age  annual Salary  credit card debt    net worth  \
# 0  41.851720    62812.09301      11609.380910  238961.2505
# 1  40.870623    66646.89292       9572.957136  530973.9078
# 2  43.152897    53798.55112      11160.355060  638467.1773
# 3  58.271369    79370.03798      14426.164850  548599.0524
# 4  57.313749    59729.15130       5358.712177  560304.0671
#
#    car purchase amount
# 0          35321.45877
# 1          45115.52566
# 2          42925.70921
# 3          67422.36313
# 4          55915.46248

# %% [markdown]
# data above is the result from the DataFrame `df` after columns that contains 'customer name', 'customer e-mail', 'country', and 'gender' being dropped.
#
#
# ---

# %%
# Displaying concise information about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  500 non-null    float64
#  1   annual Salary        500 non-null    float64
#  2   credit card debt     500 non-null    float64
#  3   net worth            500 non-null    float64
#  4   car purchase amount  500 non-null    float64
# dtypes: float64(5)
# memory usage: 19.7 KB

# %% [markdown]
#  The `info()` method provides a concise summary of the DataFrame `df`. It includes information about the data types of each column, the number of non-null values, and the memory usage. This is a quick way to get an overview of the dataset's structure and the presence of any missing values.

# %%
# Checking and counting missing values in each column
df.isna().sum()
# Out:
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %% [markdown]
# ---
#
# The `isna()` method is used to create a DataFrame of the same shape as `df`, where each element is a boolean value indicating whether the corresponding element in `df` is missing (NaN) or not. The `sum()` method is then applied to count the number of True values (missing values) along each column, providing a series that displays the count of missing values for each respective column in the DataFrame. This is a crucial step in identifying and addressing any potential missing data in the dataset.
#
#
# ---

# %%
# Creating a scatter plot to explore the relationship between 'annual Salary' and 'credit card debt'
plt.scatter(df['annual Salary'] , df['credit card debt'])
plt.xlabel('annual Salary')
plt.ylabel('credit card debt')
plt.title('the corr between credit card debt and annual Salary')
# Out:
# Text(0.5, 1.0, 'the corr between credit card debt and annual Salary')

# %% [markdown]
# The code above utilizes Matplotlib to create a scatter plot. Here's a breakdown of each line:
#
# 1. `plt.scatter(df['annual Salary'] , df['credit card debt'])`:
#    - This line generates a scatter plot using the 'annual Salary' column on the x-axis and the 'credit card debt' column on the y-axis. It visualizes the relationship between these two variables, displaying individual data points on the plot.
#
# 2. `plt.xlabel('annual Salary')`:
#    - This line adds a label to the x-axis of the scatter plot, specifying that the 'annual Salary' column represents the values along this axis.
#
# 3. `plt.ylabel('credit card debt')`:
#    - Similarly, this line adds a label to the y-axis, indicating that the 'credit card debt' column represents the values along this axis.
#
# 4. `plt.title('the corr between credit card debt and annual Salary')`:
#    - This line sets the title of the scatter plot, providing additional context. The title suggests an exploration of the correlation between 'credit card debt' and 'annual Salary', although it's worth noting that correlation does not imply causation.
#
#
# ---

# %%
# Creating a pair plot using Seaborn to visualize relationships between all numerical columns
sns.pairplot(df)

# %% [markdown]
# The provided line of code uses Seaborn's `pairplot` function to create a matrix of scatterplots for all numerical columns in the DataFrame `df`. Each scatterplot visualizes the relationship between pairs of variables, allowing for a quick overview of the dataset's pairwise relationships. The diagonal of the matrix typically displays histograms for each individual variable, providing insights into their distributions. This type of plot is useful for identifying potential patterns, trends, and correlations between different features in the dataset. It can be especially helpful in exploratory data analysis to gain a comprehensive understanding of the data's structure and relationships.
#
# ---

# %%
# Selecting features (X) and the target variable (y) from the DataFrame
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %% [markdown]
# In the first line, `X = df.iloc[:, :-1]`, the code extracts the features for machine learning from the DataFrame `df`. The `iloc` method is used to select all rows (`:`) and all columns except the last one (`:-1`), forming a new DataFrame `X` that contains the input variables.
#
# The second line, `y = df.iloc[:, -1]`, extracts the target variable from the DataFrame `df`. By using `iloc` again, it selects all rows (`:`) and only the last column (`-1`), creating a Series `y` that holds the values of the target variable. In a typical supervised learning scenario, `X` represents the input features, and `y` represents the corresponding target variable that a machine learning model will aim to predict. This separation is crucial for training and evaluating machine learning models effectively 🚀

# %% [markdown]
# # **Preprocessing**

# %%
# Scaling features using MinMaxScaler and splitting the dataset
scale = MinMaxScaler()
X = scale.fit_transform(X)
y = scale.fit_transform(y.values.reshape(-1, 1))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %% [markdown]
# `scale = MinMaxScaler()`:
#
# An instance of MinMaxScaler is created. This scaler is commonly used for scaling numerical features to a specific range, often between 0 and 1.
#
# `X = scale.fit_transform(X)`:
#
# The fit_transform method of the scaler is applied to the features (input variables) X. It scales the numerical features in X to the specified range, transforming them into a new scaled version.
#
# `y = scale.fit_transform(y.values.reshape(-1, 1))`:
#
# Similarly, the target variable y is transformed using the scaler. Since MinMaxScaler expects a 2D array as input, the reshape(-1, 1) method is used to convert the 1D array y into a 2D array before scaling.
#
# `X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)`:
#
# The dataset, consisting of the scaled features (X) and target variable (y), is split into training and testing sets using train_test_split with 80% of the data used for training and 20% for testing.

# %% [markdown]
# # **Linear Regression**

# %%
#Trying linear regression
lreg = LinearRegression()
lreg.fit(X_train, y_train)
print('Train score', lreg.score(X_train, y_train))
print('Test score', lreg.score(X_test, y_test))
# Out:
# Train score 0.9999999818041129
# Test score 0.9999999788904089

# %% [markdown]
# The linear regression model is trained using the `LinearRegression` class from scikit-learn. The model is fitted to the scaled training data (`X_train` and `y_train`). Subsequently, the code prints the R-squared scores, which indicate how well the model fits the training and testing datasets. R-squared ranges from 0 to 1, with higher values indicating a better fit. The training score represents the model's performance on the data it was trained on, while the testing score evaluates its ability to generalize to new, unseen data. Comparing these scores helps assess the model's effectiveness and potential for overfitting.

# %%
# Making predictions using the trained Linear Regression model on the test set features
y_pred = lreg.predict(X_test)

# %% [markdown]
# I use the trained linear regression model (`lreg`) to make predictions on the test set features (`X_test`). The `predict` method takes the test features as input and produces corresponding predictions for the target variable. The resulting predictions are stored in the variable `y_pred`. After this step, you can compare these predictions (`y_pred`) with the actual target values (`y_test`) to assess the model's performance on the unseen test data.

# %% [markdown]
# # **ANN Model**

# %%
# Creating and training an Artificial Neural Network (ANN)
ann = Sequential([Dense(32, activation="relu"),
                 Dense(1, activation='linear')])

ann.compile(optimizer='adam',
            loss='mean_squared_error',
            metrics=['mean_absolute_error'])


history = ann.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 31ms/step - loss: 0.4048 - mean_absolute_error: 0.6075 - val_loss: 0.3109 - val_mean_absolute_error: 0.5345
# Epoch 2/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2315 - mean_absolute_error: 0.4499 - val_loss: 0.1654 - val_mean_absolute_error: 0.3810
# Epoch 3/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1139 - mean_absolute_error: 0.3057 - val_loss: 0.0757 - val_mean_absolute_error: 0.2466
# Epoch 4/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0494 - mean_absolute_error: 0.1862 - val_loss: 0.0293 - val_mean_absolute_error: 0.1414
# Epoch 5/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0200 - mean_absolute_error: 0.1111 - val_loss: 0.0126 - val_mean_absolute_error: 0.0890
# Epoch 6/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0123 - mean_absolute_error: 0.0880 - val_loss: 0.0092 - val_mean_absolute_error: 0.0786
# ...

# %% [markdown]
# ---
# In this code , I'm creating and training an artificial neural network (ANN) using the Keras library with TensorFlow backend:
#
# 1. `ann = Sequential([Dense(32, activation="relu"), Dense(1, activation='linear')])`:
#    - A sequential model (`ann`) is defined, consisting of two layers. The first layer has 32 neurons and uses the ReLU activation function, while the second layer has a single neuron with a linear activation function.
#
# 2. `ann.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])`:
#    - The model is configured for training using the `compile` method. The 'adam' optimizer is chosen, 'mean_squared_error' is set as the loss function (suitable for regression tasks), and 'mean_absolute_error' is chosen as the metric to monitor during training.
#
# 3. `history = ann.fit(X_train, y_train, epochs=50, validation_split=0.2)`:
#    - The model is trained using the `fit` method. It takes the scaled training features (`X_train`) and target variable (`y_train`) as input and runs for 50 epochs. The training process is monitored on a validation subset (`validation_split=0.2`), allowing you to observe the model's performance on a portion of the training data not used for training. The training history is stored in the variable `history`, which can be used for plotting learning curves and evaluating model performance over epochs.

# %%
# Extracting training and validation metrics from the training history
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']

# Finding the epoch with the lowest validation loss and highest validation accuracy
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmin(val_acc)
acc_highest = val_acc[index_acc]

# Generating a list of epochs
Epochs = [i+1 for i in range(len(tr_acc))]

# Creating labels for the best epochs
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Creating a figure with two subplots for training and validation loss, and training and validation accuracy
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

# Setting the plot
plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Adjusting layout and displaying the figure
plt.tight_layout
plt.show()

# %% [markdown]
# The provided code will generate a figure with two subplots. Each subplot illustrates the changes in loss and accuracy during the training and validation of an artificial neural network (ANN). The first subplot displays the curves of training loss and validation loss over epochs, marking the epoch with the lowest validation loss. The second subplot shows the curves of training accuracy and validation accuracy, highlighting the epoch with the highest validation accuracy. This visualization is valuable for understanding the model's performance throughout the training and validation processes, pinpointing the epochs with the best loss and accuracy on the validation dataset.

# %%
# Making predictions using the trained linear regression model on the test set
ann_y_pred = ann.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 7ms/step

# %% [markdown]
# In this line, I am using the trained artificial neural network (ANN), represented by the variable `ann`, to make predictions on the test set features `(X_test)`. The `predict` method takes the scaled test features as input `(X_test)` and produces predicted values for the target variable. These predictions are stored in the variable `ann_y_pred`.
#
# Now, let's proceed with evaluating the performance of the model:

# %%
# Calculating the R-squared score for the artificial neural network predictions
r2 = r2_score(y_test, y_pred)
print('R2 score:', r2)
# Out:
# R2 score: 0.9999999788904089

# %% [markdown]
# Here, I calculate the R-squared score using the `r2_score` function from scikit-learn. It takes the actual target values (`y_test`) and the predicted values (`ann_y_pred`) as inputs. The R-squared score is a measure of how well the model's predictions align with the actual values. A higher R-squared score indicates a better fit. Finally, the code prints the R2 score, providing you with an assessment of the artificial neural network's performance on the unseen test data.

# %%
# Using the trained artificial neural network (ANN) to evaluate its performance on the test set
ann.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0016 - mean_absolute_error: 0.0321
# [0.0016421903856098652, 0.032067347317934036]

# %% [markdown]
# In this line, I'm employing the `evaluate` method on the artificial neural network (ANN) model. This method evaluates the model's performance on a specific dataset, which, in this case, is the test set. The `X_test` contains the features of the test set, and `y_test` holds the corresponding target variable values.

# %%
# Making predictions using the trained artificial neural network (ANN) on a new input
ann.predict([[40, 70000.500, 9550,534000]])
# Out:
# 1/1 [==============================] - 0s 37ms/step
# array([[157356.16]], dtype=float32)

# %% [markdown]
# In this line, I'm using the trained artificial neural network (ANN) to make predictions on a new input. The input is represented by the list `[[40, 70000.500, 9550, 534000]]`, where each element corresponds to a feature such as age, annual salary, credit card debt, and net worth.

# %%
# Creating a scatter plot to compare predictions of Linear Regression and Artificial Neural Network (ANN)
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, label='Linear Regression')
plt.scatter(y_test, ann_y_pred, label='ANN')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='gray')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs. Actual Values')
plt.legend()
plt.show()

# %% [markdown]
# I'm generating a scatter plot to visually compare the predictions made by both the Linear Regression model (`y_pred`) and the Artificial Neural Network (ANN) model (`ann_y_pred`) against the actual target values (`y_test`). The scatter plot includes points for both models, with the x-axis representing the actual values (`y_test`) and the y-axis representing the predicted values. Additionally, a diagonal dashed line is plotted to indicate where points would lie if predictions perfectly matched the actual values.
#
# This visualization allows for a qualitative assessment of how well the models' predictions align with the actual values, providing insights into their performance on the test dataset. The legend distinguishes between the Linear Regression and ANN models in the plot.

# %%
# Convert y_test to binary labels (if it's not already)
y_test_binary = (y_test >= 0.5).astype(int)

# %% [markdown]
# In this line, I am converting the continuous values in `y_test` into binary labels. This step is crucial for classification tasks. Here, we've set a threshold of 0.5. Any value equal to or greater than 0.5 is assigned the label 1, and values below 0.5 are assigned the label 0. This binary transformation allows us to compare predicted and actual labels effectively.

# %%
# Generating confusion matrix for the test set
conf_matrix_total = confusion_matrix(y_test_binary, y_pred_classes)

# %% [markdown]
# Now, I compute the confusion matrix using scikit-learn's `confusion_matrix` function. The confusion matrix is a valuable tool in evaluating classification models. It breaks down the model's predictions into categories such as true positives, true negatives, false positives, and false negatives. In this context, it's calculated based on the binary labels in `y_test_binary` and the predicted classes in `y_pred_classes`.

# %%
# Plotting confusion matrix with a grey colormap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_total, annot=True, fmt='d', cmap='autumn', cbar=False)
plt.xlabel('ANN Predicted label')
plt.ylabel('Actual label')
plt.title('Confusion Matrix (Total Data)')
plt.show()

# %%
# Generating and displaying classification report
class_report_total = classification_report(y_test_binary, y_pred_classes)
print("Classification Report (Total Data):\n", class_report_total)
# Out:
# Classification Report (Total Data):
#                precision    recall  f1-score   support
#
#            0       0.53      1.00      0.69        53
#            1       0.00      0.00      0.00        47
#
#     accuracy                           0.53       100
#    macro avg       0.27      0.50      0.35       100
# weighted avg       0.28      0.53      0.37       100
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# In these lines, we are generating a classification report using scikit-learn's `classification_report` function. The classification report is a comprehensive summary of the model's performance, providing metrics such as precision, recall, F1-score, and support for each class. It takes the true binary labels (`y_test_binary`) and the predicted classes (`y_pred_classes`) as input.
#
# The classification report includes the following metrics:
#
# 1. Precision: the ratio of true positive predictions to the total predicted positives.
# 2. Recall: the ratio of true positive predictions to the total actual positives.
# 3. F1-score: the harmonic mean of precision and recall, providing a balanced measure.
# 4. Support: the number of actual occurrences of each class.
# Printing the classification report allows us to assess the model's performance in more detail, helping to understand how well it is classifying instances in each class.
